# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevin-1992/Customer-service-Airline/blob/main/Hangman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print ("welcome to the NHK Hangman game")
play = input("Do you want to play Hangman? Y/N ")
while play == "Y":
  wordlist = ["coconut","orange","apple","hamburger","house","tea","car","deutchland","sunglasses","noir","sphinx","army","dammned","skull","shark","typhoon","storm"]
  selectedword = random.choice(wordlist)
  lenselectedword =len(selectedword)
  filler = ("■")
  blank =[]
  blank2=[]
  counter = (0)
  #Computer selects a random word and creates blanks
  for i in range(0,lenselectedword):
    blank.append(filler)
  for i in range(0,lenselectedword):
    blank2.append(filler)
  def split(selectedword):
    return [char for char in selectedword] 
  selectedword2 = split(selectedword)
  selectedword3 = split(selectedword)
  print("""
      _________
      |/   |      
      |              
      |                
      |                 
      |               
      |                   
      |___  """)
  print(blank)
  while counter < 6 and blank != selectedword2:
    #adding words to the list and adding counter to list of tries
    playerword = input("type your letter ")
    playerword = playerword.lower()
    playerwordlist=[]
    #replacing 0 on blank
    for i, item in enumerate(selectedword2):
      if item == playerword:
        blank[i] = playerword
    if blank != blank2:
      for i, item in enumerate(selectedword2):
        if item == playerword:
          blank2[i] = playerword
    else:
      counter = counter+1
    if counter == 0:
      print("""
      _________
      |/   |      
      |              
      |                
      |                 
      |               
      |                   
      |___  """)
      print(blank)
    elif counter == 1:
      print("""
      _________
      |/   |      
      |    0         
      |                
      |                 
      |               
      |                   
      |___  """)
      print(blank)
    elif counter == 2:
      print("""
      _________
      |/   |      
      |    0         
      |    |            
      |                 
      |               
      |                   
      |___  """)
      print(blank)
    elif counter == 3:
      print("""
      _________
      |/   |      
      |    0         
      |   /|            
      |                 
      |               
      |                   
      |___  """)
      print(blank)
    elif counter == 4:
      print("""
      _________
      |/   |      
      |    0         
      |   /|\            
      |                 
      |               
      |                   
      |___  """)
      print(blank)
    elif counter == 5:
      print("""
      _________
      |/   |      
      |    0         
      |   /|\            
      |   /             
      |               
      |                   
      |___  """)
      print(blank)
    elif counter == 6:
      print("""
      _________
      |/   |      
      |    0         
      |   /|\            
      |   / \            
      |               
      |                   
      |___  """)
      print(blank)
      print("you got hanged")
      print(f"The word was{selectedword2}")
      play = input("Do you want to play Hangman? Y/N ")
    if counter <6 and selectedword3 == blank:
      print("You win the game")
      play = input("Do you want to play Hangman? Y/N ")
else:
  print("Have a nice day")
# Out:
# welcome to the NHK Hangman game
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...
